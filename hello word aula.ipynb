# %%
print ("ola mundo")
# Out:
# ola mundo

# %%
print("teste2")
# Out:
# teste2

# %%
10*2
# Out:
# 20

# %%
64/8
# Out:
# 8.0

# %%
frase ="piton para analise"

# %%
frase[0:3]
# Out:
# 'pit'

# %%
frase.upper()
# Out:
# 'PITON PARA ANALISE'

# %%
frase.count('para')
# Out:
# 1

# %%
frase.replace('para','for')
# Out:
# 'piton for analise'
